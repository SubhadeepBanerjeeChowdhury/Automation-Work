# %% [markdown]
# # Process walkthrough:
# - Access an excel file through user defined path
# - Loop through each sheet to look for unique identifiers like 'Group Name:' to identify Oxford Plans of the Table 1 format using condition given in the `collecting tables` function
# - Once Table 1 format is detected, check if there are multiple tables present in the sheet.
# - If there are more than one table in a sheet, use the `separate_table` function to separate the tables and store them individually in a list
# - If there is only 1 table in the sheet, again, store it in the same list
# - Loop over each table in the list and clean the data
# - Once cleaned, concatenate the clean dfs into a final df

# %% [markdown]
# ## Separating tables and Collecting them individually

# %%
import pandas as pd

#function to separate tables in case of multiple tables in a sheet

def separate_tables(df, df_list):
    # Convert all columns to string type
    df = df.astype(str)
    
    # Check if 'Group Name:' row exists in the DataFrame
    if df.apply(lambda x: x.str.contains('Group Name:')).any().any():
        # Find the row index where 'Group Name:' is present
        header_index = (df.apply(lambda x: x.str.contains('Group Name:')).any(axis=1)).idxmax()

        # Split the DataFrame into df1 and df2 based on the 'Group Name:' row
        df1 = df.iloc[:header_index]
        df2 = df.iloc[header_index + 1:]

        # Set the header of df2 using the 'Group Name:' row
        df2.columns = df.iloc[header_index]

        # Reset index for both DataFrames
        df1 = df1.reset_index(drop=True)
        df2 = df2.reset_index(drop=True)

        df_list.append(df1)
        df_list.append(df2)
        
    

#function to extract tables individually and store them in a list

def collecting_tables(file_path):
    # Read the Excel file
    xls = pd.ExcelFile(file_path)
    
    # Initialize an empty list to store dataframes
    table_list = []
    
    # Iterate through each sheet
    for sheet_name in xls.sheet_names:
        # Read the sheet into a DataFrame
        df = pd.read_excel(file_path, header=None, sheet_name=sheet_name)
        
        # Check if "Group Name:" exists in the top-left cells
        if "Group Name:" in df.iloc[:5, :5].values:
            df = df.T
            df.columns = df.iloc[0]
            df = df[1:]
            df.dropna(axis=0, how='all', inplace=True)
            df.reset_index(inplace=True, drop=True)
            
            df=df.astype(str)
            
            
            
            if (df.applymap(lambda x: 'Group Name:' in x)).any(axis=1).any():
                separate_tables(df, table_list)
            

                for table in table_list:
                    separate_tables(table, table_list)
                table_list = [item for item in table_list if not item.apply(lambda x: x.str.contains('Group Name:')).any().any()]
                
            else:
                table_list.append(df)
            
            
        else:
            pass
    
    
    return table_list

# %%
table_list=collecting_tables(r"C:\Users\Subhadeep\Downloads\multi table oxford sheet (1).xlsx")
# Out:
# C:\Users\SUBHAD~1\AppData\Local\Temp/ipykernel_4148/4097615813.py:45: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if "Group Name:" in df.iloc[:5, :5].values:

# %%
len(table_list)
# Out:
# 7

# %%
table_list[0]
# Out:
# 0 Group Name: Group Number(or TBD)        Request Date:  \
# 0   Tesla Inc               554658  2020-04-02 00:00:00
# 1         nan                  nan                  nan
# 2         nan                  nan                  nan
# 3         nan                  nan                  nan
# 4         nan                  nan                  nan
# 5         nan                  nan                  nan
#
# 0 Effective Date or NSB:  \
# 0    2020-01-03 00:00:00
# 1                    nan
# 2                    nan
# 3                    nan
# 4                    nan
# 5                    nan
#
# 0 Please Note: All items listed on this form are subject to review  NaN  \
# 0                                                nan                nan
# 1                                                nan                nan
# 2                                                nan                nan
# 3                                                nan                nan
# 4                                                nan                nan
# 5                                                nan                nan
#
# 0                          NaN              General Information  \
# 0  Benefits Currently in Place  Current Plan 1: P0145445 BUY UP
# 1                          nan  Current Plan 2: P0145445 BUY UP
# 2                          nan  Current Plan 3: P0145445 BUY UP
# 3           Requested Benefits  Current Plan 1: P0145445 BUY UP
# 4                          nan  Current Plan 2: P0145445 BUY UP
# 5                          nan  Current Plan 3: P0145445 BUY UP
#
# 0               CSP Base (Similar standard plan) Tracking ID  \
# 0  Freedom HMO 2323                                      nan
# 1  Freedom HMO 2324                                      nan
# 2  Freedom HMO 2325                                      nan
# 3  Freedom HMO 2326                     KACTOHP58- MNS000025
# 4  Freedom HMO 2327                     KACTOHP58- MNS000026
# 5  Freedom HMO 2328                     KACTOHP58- MNS000027
#
# 0 No of Employees Enrolled: Group State (NY,NJ,CT) Market (Large or Small)  \
# 0                        23                     NJ                   Large
# 1                        25                     NJ                   Large
# 2                        45                     NJ                   Large
# 3                        36                     NJ                   Large
# 4                        26                     NJ                   Large
# 5                        15                     NJ                   Large
#
# 0 Product     Access  Network In Network (IN) PCP/Specialist OV Copay  \
# 0     HMO  Non Gated  Freedom             nan                   30/45
# 1     HMO  Non Gated  Freedom             nan                   30/50
# 2     HMO  Non Gated  Freedom             nan                     0/0
# 3     HMO  Non Gated  Freedom             nan                   30/55
# 4     HMO  Non Gated  Freedom             nan                   30/60
# 5     HMO  Non Gated  Freedom             nan                     0/1
#
# 0 ER Cost Share                           Hospital Cost Share   \
# 0           150  IP: 0 after deductible OP: 0 after deductible
# 1           160  IP: 0 after deductible OP: 0 after deductible
# 2           nan  IP: 0 after deductible OP: 0 after deductible
# 3           nan  IP: 0 after deductible OP: 0 after deductible
# 4           nan  IP: 0 after deductible OP: 0 after deductible
# 5           nan  IP: 0 after deductible OP: 0 after deductible
#
# 0 For Direct, EPO or Value Option Products IN Deductible IN Coinsurance %  \
# 0                                      nan     2500/5000              100
# 1                                      nan     2500/5000               90
# 2                                      nan     2500/5001               91
# 3                                      nan     2500/5002               92
# 4                                      nan     2500/5003               93
# 5                                      nan     2500/5004               94
#
# 0 IN Coinsurance Limit IN Out of Pocket Maximum Out of Network (OON):  \
# 0            3000/6000                3000/6001                   nan
# 1          32000/50000              32000/50000                   nan
# 2          32000/50001              32000/50001                   nan
# 3          32000/50002              32000/50002                   nan
# 4          32000/50003              32000/50003                   nan
# 5          32000/50004              32000/50004                   nan
#
# 0 OON Deductible OON Coinsurance % OON Coinsurance Limit  \
# 0      2500/5002                92           32000/50002
# 1      2500/5003                93           32000/50003
# 2      2500/5004                94           32000/50004
# 3      2500/5002                92           32000/50002
# 4      2500/5003                93           32000/50003
# 5      2500/5004                94           32000/50004
#
# 0 OON Out of Pocket Maximum  NaN
# 0               32000/50002  nan
# 1               32000/50003  nan
# 2               32000/50004  nan
# 3               32000/50002  nan
# 4               32000/50003  nan
# 5               32000/50004  nan

# %% [markdown]
# ## Cleaning the data

# %%
import pandas as pd
import numpy as np
def clean_data(df_list):
    dfs = []
    
    for df in df_list:
        df.replace('nan', np.nan, inplace=True)
        df['Group Name:']=df['Group Name:'].fillna(df['Group Name:'].iloc[0])
        df['Group Number(or TBD)']=df['Group Number(or TBD)'].fillna(df['Group Number(or TBD)'].iloc[0])
        df['Request Date:']=df['Request Date:'].fillna(df['Request Date:'].iloc[0])
        df['Effective Date or NSB:']=df['Effective Date or NSB:'].fillna(df['Effective Date or NSB:'].iloc[0])
        
        
        # Rename columns to strings
        df.columns = [str(column) for column in df.columns]
        
        # Iterate through each column to check for 'Requested Benefits' in string columns
        for column in df.select_dtypes(include='object').columns:
            if any(df[column].apply(lambda x: 'Requested Benefits' in str(x))):
                df.rename(columns={column: 'Benefits Status'}, inplace=True)

        # Fill missing values in 'Benefits Status' column with forward fill
        df['Benefits Status']=df['Benefits Status'].fillna(method='ffill')

        # Rename 'General Information' column to 'Plan Information'
        df.rename(columns={'General Information': 'Plan Information'}, inplace=True)
        df.dropna(axis=1, how='all', inplace=True)
        df.dropna(how='all', inplace=True)


        # Set display option to show all columns
        pd.set_option('display.max_columns', None)
        
        dfs.append(df.reset_index(drop=True))  # Reset index of each DataFrame
        
    return dfs

# Example usage:
clean_dfs = clean_data(table_list)

# %%
len(clean_dfs)
# Out:
# 7

# %% [markdown]
# ### This is how each df looks like now

# %%
clean_dfs[0]
# Out:
#   Group Name: Group Number(or TBD)        Request Date:  \
# 0   Tesla Inc               554658  2020-04-02 00:00:00
# 1   Tesla Inc               554658  2020-04-02 00:00:00
# 2   Tesla Inc               554658  2020-04-02 00:00:00
# 3   Tesla Inc               554658  2020-04-02 00:00:00
# 4   Tesla Inc               554658  2020-04-02 00:00:00
# 5   Tesla Inc               554658  2020-04-02 00:00:00
#
#   Effective Date or NSB:              Benefits Status  \
# 0    2020-01-03 00:00:00  Benefits Currently in Place
# 1    2020-01-03 00:00:00  Benefits Currently in Place
# 2    2020-01-03 00:00:00  Benefits Currently in Place
# 3    2020-01-03 00:00:00           Requested Benefits
# 4    2020-01-03 00:00:00           Requested Benefits
# 5    2020-01-03 00:00:00           Requested Benefits
#
#                   Plan Information               CSP  \
# 0  Current Plan 1: P0145445 BUY UP  Freedom HMO 2323
# 1  Current Plan 2: P0145445 BUY UP  Freedom HMO 2324
# 2  Current Plan 3: P0145445 BUY UP  Freedom HMO 2325
# 3  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 4  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 5  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
#
#   Base (Similar standard plan) Tracking ID No of Employees Enrolled:  \
# 0                                      nan                        23
# 1                                      nan                        25
# 2                                      nan                        45
# 3                     KACTOHP58- MNS000025                        36
# 4                     KACTOHP58- MNS000026                        26
# 5                     KACTOHP58- MNS000027                        15
#
#   Group State (NY,NJ,CT) Market (Large or Small) Product     Access  Network  \
# 0                     NJ                   Large     HMO  Non Gated  Freedom
# 1                     NJ                   Large     HMO  Non Gated  Freedom
# 2                     NJ                   Large     HMO  Non Gated  Freedom
# 3                     NJ                   Large     HMO  Non Gated  Freedom
# 4                     NJ                   Large     HMO  Non Gated  Freedom
# 5                     NJ                   Large     HMO  Non Gated  Freedom
#
#   PCP/Specialist OV Copay ER Cost Share  \
# 0                   30/45           150
# 1                   30/50           160
# 2                     0/0           nan
# 3                   30/55           nan
# 4                   30/60           nan
# 5                     0/1           nan
#
#                             Hospital Cost Share  IN Deductible  \
# 0  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 1  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 2  IP: 0 after deductible OP: 0 after deductible     2500/5001
# 3  IP: 0 after deductible OP: 0 after deductible     2500/5002
# 4  IP: 0 after deductible OP: 0 after deductible     2500/5003
# 5  IP: 0 after deductible OP: 0 after deductible     2500/5004
#
#   IN Coinsurance % IN Coinsurance Limit IN Out of Pocket Maximum  \
# 0              100            3000/6000                3000/6001
# 1               90          32000/50000              32000/50000
# 2               91          32000/50001              32000/50001
# 3               92          32000/50002              32000/50002
# 4               93          32000/50003              32000/50003
# 5               94          32000/50004              32000/50004
#
#   OON Deductible OON Coinsurance % OON Coinsurance Limit  \
# 0      2500/5002                92           32000/50002
# 1      2500/5003                93           32000/50003
# 2      2500/5004                94           32000/50004
# 3      2500/5002                92           32000/50002
# 4      2500/5003                93           32000/50003
# 5      2500/5004                94           32000/50004
#
#   OON Out of Pocket Maximum     MNS ID1
# 0               32000/50002         NaN
# 1               32000/50003         NaN
# 2               32000/50004         NaN
# 3               32000/50002  MNS0000025
# 4               32000/50003  MNS0000026
# 5               32000/50004  MNS0000027

# %% [markdown]
# ## FUNCTION TO GET MNS IDS

# %%
import pandas as pd
import re

def fetch_mns_ids(string):
    mns_ids = re.findall(r'MNS\D*\s*\w+', string)
    standard_mns_ids=[]
    for mns_id in mns_ids:
        mns_id = re.sub(r'MNS\s*', 'MNS', mns_id)
        
        numeric_match = re.search(r'MNS\D*(\d+)', mns_id)
        if numeric_match:
            digits = numeric_match.group(1)
            # Ensure the number of digits is 7
            digits = digits.zfill(7)
            # Reconstruct the MNS ID with padded zeros
            mns_id = 'MNS' + digits
            standard_mns_ids.append(mns_id)
        else:
            standard_mns_ids.append('')
    
    return standard_mns_ids



def get_mns(df):
    df.fillna('nan',inplace=True)
# Loop through each column
    for column in df.columns:
        # Check if 'MNS' is present anywhere in the column
        if df[column].astype(str).str.contains('MNS').any():
            # Apply the function to extract MNS IDs
            mns_ids = df[column].apply(fetch_mns_ids)

    df['MNS IDs']=mns_ids
    max_mns_ids_count = max(len(ids) for ids in mns_ids)
    padded_mns_ids = [ids + [np.NaN] * (max_mns_ids_count - len(ids)) for ids in mns_ids]
    for i in range(max_mns_ids_count):
        df[f'MNS ID{i+1}'] = [ids[i] if ids and len(ids) > i else None for ids in padded_mns_ids]
    

    df.drop(columns='MNS IDs',inplace=True)

    return df

# %%
get_mns(clean_dfs[0])
# Out:
#   Group Name: Group Number(or TBD)        Request Date:  \
# 0   Tesla Inc               554658  2020-04-02 00:00:00
# 1   Tesla Inc               554658  2020-04-02 00:00:00
# 2   Tesla Inc               554658  2020-04-02 00:00:00
# 3   Tesla Inc               554658  2020-04-02 00:00:00
# 4   Tesla Inc               554658  2020-04-02 00:00:00
# 5   Tesla Inc               554658  2020-04-02 00:00:00
#
#   Effective Date or NSB:              Benefits Status  \
# 0    2020-01-03 00:00:00  Benefits Currently in Place
# 1    2020-01-03 00:00:00  Benefits Currently in Place
# 2    2020-01-03 00:00:00  Benefits Currently in Place
# 3    2020-01-03 00:00:00           Requested Benefits
# 4    2020-01-03 00:00:00           Requested Benefits
# 5    2020-01-03 00:00:00           Requested Benefits
#
#                   Plan Information               CSP  \
# 0  Current Plan 1: P0145445 BUY UP  Freedom HMO 2323
# 1  Current Plan 2: P0145445 BUY UP  Freedom HMO 2324
# 2  Current Plan 3: P0145445 BUY UP  Freedom HMO 2325
# 3  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 4  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 5  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
#
#   Base (Similar standard plan) Tracking ID No of Employees Enrolled:  \
# 0                                      nan                        23
# 1                                      nan                        25
# 2                                      nan                        45
# 3                     KACTOHP58- MNS000025                        36
# 4                     KACTOHP58- MNS000026                        26
# 5                     KACTOHP58- MNS000027                        15
#
#   Group State (NY,NJ,CT) Market (Large or Small) Product     Access  Network  \
# 0                     NJ                   Large     HMO  Non Gated  Freedom
# 1                     NJ                   Large     HMO  Non Gated  Freedom
# 2                     NJ                   Large     HMO  Non Gated  Freedom
# 3                     NJ                   Large     HMO  Non Gated  Freedom
# 4                     NJ                   Large     HMO  Non Gated  Freedom
# 5                     NJ                   Large     HMO  Non Gated  Freedom
#
#   PCP/Specialist OV Copay ER Cost Share  \
# 0                   30/45           150
# 1                   30/50           160
# 2                     0/0           nan
# 3                   30/55           nan
# 4                   30/60           nan
# 5                     0/1           nan
#
#                             Hospital Cost Share  IN Deductible  \
# 0  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 1  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 2  IP: 0 after deductible OP: 0 after deductible     2500/5001
# 3  IP: 0 after deductible OP: 0 after deductible     2500/5002
# 4  IP: 0 after deductible OP: 0 after deductible     2500/5003
# 5  IP: 0 after deductible OP: 0 after deductible     2500/5004
#
#   IN Coinsurance % IN Coinsurance Limit IN Out of Pocket Maximum  \
# 0              100            3000/6000                3000/6001
# 1               90          32000/50000              32000/50000
# 2               91          32000/50001              32000/50001
# 3               92          32000/50002              32000/50002
# 4               93          32000/50003              32000/50003
# 5               94          32000/50004              32000/50004
#
#   OON Deductible OON Coinsurance % OON Coinsurance Limit  \
# 0      2500/5002                92           32000/50002
# 1      2500/5003                93           32000/50003
# 2      2500/5004                94           32000/50004
# 3      2500/5002                92           32000/50002
# 4      2500/5003                93           32000/50003
# 5      2500/5004                94           32000/50004
#
#   OON Out of Pocket Maximum     MNS ID1
# 0               32000/50002         NaN
# 1               32000/50003         NaN
# 2               32000/50004         NaN
# 3               32000/50002  MNS0000025
# 4               32000/50003  MNS0000026
# 5               32000/50004  MNS0000027

# %% [markdown]
# ## Concatenating All the dfs

# %%
def combine_data(clean_dfs):
    concatenated_df = pd.concat(clean_dfs, ignore_index=True)
    return concatenated_df


# Example usage:
final_df = combine_data(clean_dfs)
final_df
# Out:
#    Group Name: Group Number(or TBD)        Request Date:  \
# 0    Tesla Inc               554658  2020-04-02 00:00:00
# 1    Tesla Inc               554658  2020-04-02 00:00:00
# 2    Tesla Inc               554658  2020-04-02 00:00:00
# 3    Tesla Inc               554658  2020-04-02 00:00:00
# 4    Tesla Inc               554658  2020-04-02 00:00:00
# 5    Tesla Inc               554658  2020-04-02 00:00:00
# 6   Tienam Inc               554556  2020-04-02 00:00:00
# 7   Tienam Inc               554556  2020-04-02 00:00:00
# 8   Tienam Inc               554556  2020-04-02 00:00:00
# 9   Tienam Inc               554556  2020-04-02 00:00:00
# 10  Tienam Inc               554556  2020-04-02 00:00:00
# 11  Tienam Inc               554556  2020-04-02 00:00:00
# 12     XYZ Inc               554556  2020-04-02 00:00:00
# 13     XYZ Inc               554556  2020-04-02 00:00:00
# 14     XYZ Inc               554556  2020-04-02 00:00:00
# 15     XYZ Inc               554556  2020-04-02 00:00:00
# 16     XYZ Inc               554556  2020-04-02 00:00:00
# 17     XYZ Inc               554556  2020-04-02 00:00:00
# 18  Soumik Inc               554556  2020-04-02 00:00:00
# 19  Soumik Inc               554556  2020-04-02 00:00:00
# 20  Soumik Inc               554556  2020-04-02 00:00:00
# 21  Soumik Inc               554556  2020-04-02 00:00:00
# 22  Soumik Inc               554556  2020-04-02 00:00:00
# 23  Soumik Inc               554556  2020-04-02 00:00:00
# 24  Pramit Inc               554556  2020-04-02 00:00:00
# 25  Pramit Inc               554556  2020-04-02 00:00:00
# 26  Pramit Inc               554556  2020-04-02 00:00:00
# 27  Pramit Inc               554556  2020-04-02 00:00:00
# 28  Pramit Inc               554556  2020-04-02 00:00:00
# 29  Pramit Inc               554556  2020-04-02 00:00:00
# 30   Apple Inc               554658  2020-04-02 00:00:00
# 31   Apple Inc               554658  2020-04-02 00:00:00
# 32   Apple Inc               554658  2020-04-02 00:00:00
# 33   Apple Inc               554658  2020-04-02 00:00:00
# 34   Apple Inc               554658  2020-04-02 00:00:00
# 35   Apple Inc               554658  2020-04-02 00:00:00
# 36  ABCDEF Inc               554658  2020-04-02 00:00:00
# 37  ABCDEF Inc               554658  2020-04-02 00:00:00
# 38  ABCDEF Inc               554658  2020-04-02 00:00:00
# 39  ABCDEF Inc               554658  2020-04-02 00:00:00
# 40  ABCDEF Inc               554658  2020-04-02 00:00:00
# 41  ABCDEF Inc               554658  2020-04-02 00:00:00
#
#    Effective Date or NSB:              Benefits Status  \
# 0     2020-01-03 00:00:00  Benefits Currently in Place
# 1     2020-01-03 00:00:00  Benefits Currently in Place
# 2     2020-01-03 00:00:00  Benefits Currently in Place
# 3     2020-01-03 00:00:00           Requested Benefits
# 4     2020-01-03 00:00:00           Requested Benefits
# 5     2020-01-03 00:00:00           Requested Benefits
# 6     2020-01-03 00:00:00  Benefits Currently in Place
# 7     2020-01-03 00:00:00  Benefits Currently in Place
# 8     2020-01-03 00:00:00  Benefits Currently in Place
# 9     2020-01-03 00:00:00           Requested Benefits
# 10    2020-01-03 00:00:00           Requested Benefits
# 11    2020-01-03 00:00:00           Requested Benefits
# 12    2020-01-03 00:00:00  Benefits Currently in Place
# 13    2020-01-03 00:00:00  Benefits Currently in Place
# 14    2020-01-03 00:00:00  Benefits Currently in Place
# 15    2020-01-03 00:00:00           Requested Benefits
# 16    2020-01-03 00:00:00           Requested Benefits
# 17    2020-01-03 00:00:00           Requested Benefits
# 18    2020-01-03 00:00:00  Benefits Currently in Place
# 19    2020-01-03 00:00:00  Benefits Currently in Place
# 20    2020-01-03 00:00:00  Benefits Currently in Place
# 21    2020-01-03 00:00:00           Requested Benefits
# 22    2020-01-03 00:00:00           Requested Benefits
# 23    2020-01-03 00:00:00           Requested Benefits
# 24    2020-01-03 00:00:00  Benefits Currently in Place
# 25    2020-01-03 00:00:00  Benefits Currently in Place
# 26    2020-01-03 00:00:00  Benefits Currently in Place
# 27    2020-01-03 00:00:00           Requested Benefits
# 28    2020-01-03 00:00:00           Requested Benefits
# 29    2020-01-03 00:00:00           Requested Benefits
# 30    2020-01-03 00:00:00  Benefits Currently in Place
# 31    2020-01-03 00:00:00  Benefits Currently in Place
# 32    2020-01-03 00:00:00  Benefits Currently in Place
# 33    2020-01-03 00:00:00           Requested Benefits
# 34    2020-01-03 00:00:00           Requested Benefits
# 35    2020-01-03 00:00:00           Requested Benefits
# 36    2020-01-03 00:00:00  Benefits Currently in Place
# 37    2020-01-03 00:00:00  Benefits Currently in Place
# 38    2020-01-03 00:00:00  Benefits Currently in Place
# 39    2020-01-03 00:00:00           Requested Benefits
# 40    2020-01-03 00:00:00           Requested Benefits
# 41    2020-01-03 00:00:00           Requested Benefits
#
#                    Plan Information               CSP  \
# 0   Current Plan 1: P0145445 BUY UP  Freedom HMO 2323
# 1   Current Plan 2: P0145445 BUY UP  Freedom HMO 2324
# 2   Current Plan 3: P0145445 BUY UP  Freedom HMO 2325
# 3   Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 4   Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 5   Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 6   Current Plan 1: P0145445 BUY UP  Freedom HMO 2323
# 7   Current Plan 2: P0145445 BUY UP  Freedom HMO 2324
# 8   Current Plan 3: P0145445 BUY UP  Freedom HMO 2325
# 9   Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 10  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 11  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 12  Current Plan 1: P0145445 BUY UP  Freedom HMO 2323
# 13  Current Plan 2: P0145445 BUY UP  Freedom HMO 2324
# 14  Current Plan 3: P0145445 BUY UP  Freedom HMO 2325
# 15  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 16  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 17  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 18  Current Plan 1: P0145445 BUY UP  Freedom HMO 2323
# 19  Current Plan 2: P0145445 BUY UP  Freedom HMO 2324
# 20  Current Plan 3: P0145445 BUY UP  Freedom HMO 2325
# 21  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 22  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 23  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 24  Current Plan 1: P0145445 BUY UP  Freedom HMO 2323
# 25  Current Plan 2: P0145445 BUY UP  Freedom HMO 2324
# 26  Current Plan 3: P0145445 BUY UP  Freedom HMO 2325
# 27  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 28  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 29  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 30  Current Plan 1: P0145445 BUY UP  Freedom HMO 2323
# 31  Current Plan 2: P0145445 BUY UP  Freedom HMO 2324
# 32  Current Plan 3: P0145445 BUY UP  Freedom HMO 2325
# 33  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 34  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 35  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 36  Current Plan 1: P0145445 BUY UP  Freedom HMO 2323
# 37  Current Plan 2: P0145445 BUY UP  Freedom HMO 2324
# 38  Current Plan 3: P0145445 BUY UP  Freedom HMO 2325
# 39  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 40  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 41  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
#
#    Base (Similar standard plan) Tracking ID No of Employees Enrolled:  \
# 0                                       NaN                        23
# 1                                       NaN                        25
# 2                                       NaN                        45
# 3                      KACTOHP58- MNS000025                        36
# 4                      KACTOHP58- MNS000026                        26
# 5                      KACTOHP58- MNS000027                        15
# 6                                       NaN                        23
# 7                                       NaN                        25
# 8                                       NaN                        45
# 9                      KACTOHP58- MNS000025                        36
# 10                     KACTOHP58- MNS000026                        26
# 11                     KACTOHP58- MNS000027                        15
# 12                                      NaN                        23
# 13                                      NaN                        25
# 14                                      NaN                        45
# 15                     KACTOHP58- MNS000025                        36
# 16                     KACTOHP58- MNS000026                        26
# 17                     KACTOHP58- MNS000027                        15
# 18                                      NaN                        23
# 19                                      NaN                        25
# 20                                      NaN                        45
# 21                     KACTOHP58- MNS000025                        36
# 22                     KACTOHP58- MNS000026                        26
# 23                     KACTOHP58- MNS000027                        15
# 24                                      NaN                        23
# 25                                      NaN                        25
# 26                                      NaN                        45
# 27                     KACTOHP58- MNS000025                        36
# 28                     KACTOHP58- MNS000026                        26
# 29                     KACTOHP58- MNS000027                        15
# 30                                      NaN                        23
# 31                                      NaN                        25
# 32                                      NaN                        45
# 33                     KACTOHP58- MNS000025                        36
# 34                     KACTOHP58- MNS000026                        26
# 35                     KACTOHP58- MNS000027                        15
# 36                                      NaN                        23
# 37                                      NaN                        25
# 38                                      NaN                        45
# 39                     KACTOHP58- MNS000025                        36
# 40                     KACTOHP58- MNS000026                        26
# 41                     KACTOHP58- MNS000027                        15
#
#    Group State (NY,NJ,CT) Market (Large or Small) Product     Access  Network  \
# 0                      NJ                   Large     HMO  Non Gated  Freedom
# 1                      NJ                   Large     HMO  Non Gated  Freedom
# 2                      NJ                   Large     HMO  Non Gated  Freedom
# 3                      NJ                   Large     HMO  Non Gated  Freedom
# 4                      NJ                   Large     HMO  Non Gated  Freedom
# 5                      NJ                   Large     HMO  Non Gated  Freedom
# 6                      NJ                   Large     HMO  Non Gated  Freedom
# 7                      NJ                   Large     HMO  Non Gated  Freedom
# 8                      NJ                   Large     HMO  Non Gated  Freedom
# 9                      NJ                   Large     HMO  Non Gated  Freedom
# 10                     NJ                   Large     HMO  Non Gated  Freedom
# 11                     NJ                   Large     HMO  Non Gated  Freedom
# 12                     NJ                   Large     HMO  Non Gated  Freedom
# 13                     NJ                   Large     HMO  Non Gated  Freedom
# 14                     NJ                   Large     HMO  Non Gated  Freedom
# 15                     NJ                   Large     HMO  Non Gated  Freedom
# 16                     NJ                   Large     HMO  Non Gated  Freedom
# 17                     NJ                   Large     HMO  Non Gated  Freedom
# 18                     NJ                   Large     HMO  Non Gated  Freedom
# 19                     NJ                   Large     HMO  Non Gated  Freedom
# 20                     NJ                   Large     HMO  Non Gated  Freedom
# 21                     NJ                   Large     HMO  Non Gated  Freedom
# 22                     NJ                   Large     HMO  Non Gated  Freedom
# 23                     NJ                   Large     HMO  Non Gated  Freedom
# 24                     NJ                   Large     HMO  Non Gated  Freedom
# 25                     NJ                   Large     HMO  Non Gated  Freedom
# 26                     NJ                   Large     HMO  Non Gated  Freedom
# 27                     NJ                   Large     HMO  Non Gated  Freedom
# 28                     NJ                   Large     HMO  Non Gated  Freedom
# 29                     NJ                   Large     HMO  Non Gated  Freedom
# 30                     NJ                   Large     HMO  Non Gated  Freedom
# 31                     NJ                   Large     HMO  Non Gated  Freedom
# 32                     NJ                   Large     HMO  Non Gated  Freedom
# 33                     NJ                   Large     HMO  Non Gated  Freedom
# 34                     NJ                   Large     HMO  Non Gated  Freedom
# 35                     NJ                   Large     HMO  Non Gated  Freedom
# 36                     NJ                   Large     HMO  Non Gated  Freedom
# 37                     NJ                   Large     HMO  Non Gated  Freedom
# 38                     NJ                   Large     HMO  Non Gated  Freedom
# 39                     NJ                   Large     HMO  Non Gated  Freedom
# 40                     NJ                   Large     HMO  Non Gated  Freedom
# 41                     NJ                   Large     HMO  Non Gated  Freedom
#
#    PCP/Specialist OV Copay ER Cost Share  \
# 0                    30/45           150
# 1                    30/50           160
# 2                      0/0           NaN
# 3                    30/55           NaN
# 4                    30/60           NaN
# 5                      0/1           NaN
# 6                    30/45           150
# 7                    30/50           160
# 8                      0/0           NaN
# 9                    30/55           NaN
# 10                   30/60           NaN
# 11                     0/1           NaN
# 12                   30/45           150
# 13                   30/50           160
# 14                     0/0           NaN
# 15                   30/55           NaN
# 16                   30/60           NaN
# 17                     0/1           NaN
# 18                   30/45           150
# 19                   30/50           160
# 20                     0/0           NaN
# 21                   30/55           NaN
# 22                   30/60           NaN
# 23                     0/1           NaN
# 24                   30/45           150
# 25                   30/50           160
# 26                     0/0           NaN
# 27                   30/55           NaN
# 28                   30/60           NaN
# 29                     0/1           NaN
# 30                   30/45           150
# 31                   30/50           160
# 32                     0/0           NaN
# 33                   30/55           NaN
# 34                   30/60           NaN
# 35                     0/1           NaN
# 36                   30/45           150
# 37                   30/50           160
# 38                     0/0           NaN
# 39                   30/55           NaN
# 40                   30/60           NaN
# 41                     0/1           NaN
#
#                              Hospital Cost Share  IN Deductible  \
# 0   IP: 0 after deductible OP: 0 after deductible     2500/5000
# 1   IP: 0 after deductible OP: 0 after deductible     2500/5000
# 2   IP: 0 after deductible OP: 0 after deductible     2500/5001
# 3   IP: 0 after deductible OP: 0 after deductible     2500/5002
# 4   IP: 0 after deductible OP: 0 after deductible     2500/5003
# 5   IP: 0 after deductible OP: 0 after deductible     2500/5004
# 6   IP: 0 after deductible OP: 0 after deductible     2500/5000
# 7   IP: 0 after deductible OP: 0 after deductible     2500/5000
# 8   IP: 0 after deductible OP: 0 after deductible     2500/5001
# 9   IP: 0 after deductible OP: 0 after deductible     2500/5002
# 10  IP: 0 after deductible OP: 0 after deductible     2500/5003
# 11  IP: 0 after deductible OP: 0 after deductible     2500/5004
# 12  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 13  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 14  IP: 0 after deductible OP: 0 after deductible     2500/5001
# 15  IP: 0 after deductible OP: 0 after deductible     2500/5002
# 16  IP: 0 after deductible OP: 0 after deductible     2500/5003
# 17  IP: 0 after deductible OP: 0 after deductible     2500/5004
# 18  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 19  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 20  IP: 0 after deductible OP: 0 after deductible     2500/5001
# 21  IP: 0 after deductible OP: 0 after deductible     2500/5002
# 22  IP: 0 after deductible OP: 0 after deductible     2500/5003
# 23  IP: 0 after deductible OP: 0 after deductible     2500/5004
# 24  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 25  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 26  IP: 0 after deductible OP: 0 after deductible     2500/5001
# 27  IP: 0 after deductible OP: 0 after deductible     2500/5002
# 28  IP: 0 after deductible OP: 0 after deductible     2500/5003
# 29  IP: 0 after deductible OP: 0 after deductible     2500/5004
# 30  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 31  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 32  IP: 0 after deductible OP: 0 after deductible     2500/5001
# 33  IP: 0 after deductible OP: 0 after deductible     2500/5002
# 34  IP: 0 after deductible OP: 0 after deductible     2500/5003
# 35  IP: 0 after deductible OP: 0 after deductible     2500/5004
# 36  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 37  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 38  IP: 0 after deductible OP: 0 after deductible     2500/5001
# 39  IP: 0 after deductible OP: 0 after deductible     2500/5002
# 40  IP: 0 after deductible OP: 0 after deductible     2500/5003
# 41  IP: 0 after deductible OP: 0 after deductible     2500/5004
#
#    IN Coinsurance % IN Coinsurance Limit IN Out of Pocket Maximum  \
# 0               100            3000/6000                3000/6001
# 1                90          32000/50000              32000/50000
# 2                91          32000/50001              32000/50001
# 3                92          32000/50002              32000/50002
# 4                93          32000/50003              32000/50003
# 5                94          32000/50004              32000/50004
# 6               100            3000/6000                3000/6001
# 7                90          32000/50000              32000/50000
# 8                91          32000/50001              32000/50001
# 9                92          32000/50002              32000/50002
# 10               93          32000/50003              32000/50003
# 11               94          32000/50004              32000/50004
# 12              100            3000/6000                3000/6001
# 13               90          32000/50000              32000/50000
# 14               91          32000/50001              32000/50001
# 15               92          32000/50002              32000/50002
# 16               93          32000/50003              32000/50003
# 17               94          32000/50004              32000/50004
# 18              100            3000/6000                3000/6001
# 19               90          32000/50000              32000/50000
# 20               91          32000/50001              32000/50001
# 21               92          32000/50002              32000/50002
# 22               93          32000/50003              32000/50003
# 23               94          32000/50004              32000/50004
# 24              100            3000/6000                3000/6001
# 25               90          32000/50000              32000/50000
# 26               91          32000/50001              32000/50001
# 27               92          32000/50002              32000/50002
# 28               93          32000/50003              32000/50003
# 29               94          32000/50004              32000/50004
# 30              100            3000/6000                3000/6001
# 31               90          32000/50000              32000/50000
# 32               91          32000/50001              32000/50001
# 33               92          32000/50002              32000/50002
# 34               93          32000/50003              32000/50003
# 35               94          32000/50004              32000/50004
# 36              100            3000/6000                3000/6001
# 37               90          32000/50000              32000/50000
# 38               91          32000/50001              32000/50001
# 39               92          32000/50002              32000/50002
# 40               93          32000/50003              32000/50003
# 41               94          32000/50004              32000/50004
#
#    OON Deductible OON Coinsurance % OON Coinsurance Limit  \
# 0       2500/5002                92           32000/50002
# 1       2500/5003                93           32000/50003
# 2       2500/5004                94           32000/50004
# 3       2500/5002                92           32000/50002
# 4       2500/5003                93           32000/50003
# 5       2500/5004                94           32000/50004
# 6       2500/5002                92           32000/50002
# 7       2500/5003                93           32000/50003
# 8       2500/5004                94           32000/50004
# 9       2500/5002                92           32000/50002
# 10      2500/5003                93           32000/50003
# 11      2500/5004                94           32000/50004
# 12      2500/5002                92           32000/50002
# 13      2500/5003                93           32000/50003
# 14      2500/5004                94           32000/50004
# 15      2500/5002                92           32000/50002
# 16      2500/5003                93           32000/50003
# 17      2500/5004                94           32000/50004
# 18      2500/5002                92           32000/50002
# 19      2500/5003                93           32000/50003
# 20      2500/5004                94           32000/50004
# 21      2500/5002                92           32000/50002
# 22      2500/5003                93           32000/50003
# 23      2500/5004                94           32000/50004
# 24      2500/5002                92           32000/50002
# 25      2500/5003                93           32000/50003
# 26      2500/5004                94           32000/50004
# 27      2500/5002                92           32000/50002
# 28      2500/5003                93           32000/50003
# 29      2500/5004                94           32000/50004
# 30      2500/5002                92           32000/50002
# 31      2500/5003                93           32000/50003
# 32      2500/5004                94           32000/50004
# 33      2500/5002                92           32000/50002
# 34      2500/5003                93           32000/50003
# 35      2500/5004                94           32000/50004
# 36      2500/5002                92           32000/50002
# 37      2500/5003                93           32000/50003
# 38      2500/5004                94           32000/50004
# 39      2500/5002                92           32000/50002
# 40      2500/5003                93           32000/50003
# 41      2500/5004                94           32000/50004
#
#    OON Out of Pocket Maximum
# 0                32000/50002
# 1                32000/50003
# 2                32000/50004
# 3                32000/50002
# 4                32000/50003
# 5                32000/50004
# 6                32000/50002
# 7                32000/50003
# 8                32000/50004
# 9                32000/50002
# 10               32000/50003
# 11               32000/50004
# 12               32000/50002
# 13               32000/50003
# 14               32000/50004
# 15               32000/50002
# 16               32000/50003
# 17               32000/50004
# 18               32000/50002
# 19               32000/50003
# 20               32000/50004
# 21               32000/50002
# 22               32000/50003
# 23               32000/50004
# 24               32000/50002
# 25               32000/50003
# 26               32000/50004
# 27               32000/50002
# 28               32000/50003
# 29               32000/50004
# 30               32000/50002
# 31               32000/50003
# 32               32000/50004
# 33               32000/50002
# 34               32000/50003
# 35               32000/50004
# 36               32000/50002
# 37               32000/50003
# 38               32000/50004
# 39               32000/50002
# 40               32000/50003
# 41               32000/50004

# %% [markdown]
# ### Notes:
#
# - We need to consider cases where tables are arranged top to bottom. Presently the `separate_table` function only deals with tables arranged left to right
#
# - We need to include the logic to get rid additional/irrelevant texts present in the excel sheet above or below the tables
#
# - Some sheets contain 'Corrected Values', written next to the incorrect values which need to be considered.
